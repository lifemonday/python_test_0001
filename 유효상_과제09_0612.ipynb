# %%
from IPython.display import display, HTML

CSS = """
.output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
#     flex-direction: row;
# }
# </style>

# %%
from __future__ import division
from numpy.random import randn
import numpy as np
import os
import matplotlib.pyplot as plt
np.random.seed(12345)
plt.rc('figure', figsize=(10, 6))
from pandas import Series, DataFrame
import pandas
import pandas as pd
np.set_printoptions(precision=4, threshold=500)
pd.options.display.max_rows = 100
import json

# %%
df = pd.read_csv('c:/AIPython_2/titanic.csv')

# %%
df.rename(columns=str.lower, inplace=True)
df
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
age_mean=np.round(df.age.mean())
age_mean
# Out:
# 30.0

# %%
df.age.fillna(age_mean,inplace=True)
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked  agerange
# 0      0         A/5 21171   7.2500   NaN        S  (15, 60]
# 1      0          PC 17599  71.2833   C85        C  (15, 60]
# 2      0  STON/O2. 3101282   7.9250   NaN        S  (15, 60]
# 3      0            113803  53.1000  C123        S  (15, 60]
# ...

# %%
bins=(0,15,60,100)
df['agerange']=pd.cut(df.age, bins)
df
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
grouped=df.groupby(['pclass','agerange'],)

# %%
functions = [('합계','count'),('생존자','sum'),('생존율','mean')]
result = grouped['survived'].agg(functions)
result
# Out:
#                    합계  생존자       생존율
# pclass agerange
# 1      (0, 15]      6    5  0.833333
#        (15, 60]   196  128  0.653061
#        (60, 100]   14    3  0.214286
# 2      (0, 15]     19   19  1.000000
#        (15, 60]   162   67  0.413580
#        (60, 100]    3    1  0.333333
# 3      (0, 15]     58   25  0.431034
#        (15, 60]   428   93  0.217290
#        (60, 100]    5    1  0.200000

# %%
df[['survived']].groupby(df['pclass']).sum()
# Out:
#         survived
# pclass
# 1            136
# 2             87
# 3            119

# %%
df[['survived']].groupby(df['pclass']).mean()
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
bins=(0,15,60,100)
df['agerange']=pd.cut(df.age, bins)
df
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
grouped2=df.groupby(['agerange','pclass'])
grouped2['survived'].sum()
# Out:
# agerange   pclass
# (0, 15]    1           5
#            2          19
#            3          25
# (15, 60]   1         114
#            2          63
#            3          59
# (60, 100]  1           3
#            2           1
#            3           1
# Name: survived, dtype: int64

# %%
temp = grouped2['survived'].sum()/grouped2['survived'].count()

# %%
np.round(temp, decimals=2)
# Out:
# agerange   pclass
# (0, 15]    1         0.83
#            2         1.00
#            3         0.43
# (15, 60]   1         0.69
#            2         0.42
#            3         0.20
# (60, 100]  1         0.21
#            2         0.33
#            3         0.20
# Name: survived, dtype: float64
